# %%
import matplotlib.pyplot as plt
# Split the figure into 2 subplots
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121) # 121 means split into 1 row ,2 columns, and put in 1st part.
ax2 = fig.add_subplot(122) # 122 means split into 1 row ,2 columns, and put in 2nd part.

# %% [raw]
# plt.figure(figsize=(8, 4)) creates a new figure for plotting
# figsize=(8, 4)) specifies the size of the figure which is 8 inches wide and 4 inches tall
# ax1 = fig.add_subplot(121) adds a subplot to the fig and 121 means youre dividing the figure into a 1x2 grid 1 row, 2 columns and placing the subplot in the first position right side of the final output
# ax2 = fig.add_subplot(122) adds another subplot to the same figure 122 means 1x2 grid but in the 2nd position right side of the final output

# %%
labels = ['Adrian', 'Monica', 'Jared']
num = [230, 100, 98]

# Create figure and subplots (2 subplots: one for pie chart, one for bar chart)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

# Pie Chart (Subplot 1)
ax1.pie(num, labels=labels, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'yellow'])
ax1.set_title('Pie Chart (Subplot 1)')

# Bar Chart (Subplot 2)
ax2.bar(labels, num, color=['lightblue', 'lightgreen', 'yellow'])
ax2.set_title('Bar Chart (Subplot 2)')
ax2.set_xlabel('Candidate')
ax2.set_ylabel('Votes')

# Set the main title for the entire figure
fig.suptitle('Voting Results', size=14)

# Show the plot
plt.tight_layout()
plt.show()

# %% [raw]
# labels = name of the candidates, num for the number of each vote

# %% [raw]
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7)) creates a 1-row, 2 column layout of subplots. it returns fig
# ax1, ax2 the axes where to plot data. figsize=(14,7) sets the figure size to 14 inches wide and 7 inches tall

# %% [raw]
# ax1.pie(num, labels=labels, autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'yellow']) num = values of the pie slices, label for the labels of each slice, autopct='%1.1f%%' show the percentage of each slice with 1 decimal place annd lastly colors for custom color of each slices.

# %% [raw]
# ax1.set_title('Pie Chart (Subplot 1)') sets the title for the first subplot where the pie chart is shown

# %% [raw]
# ax2.bar(labels, num, color=['lightblue', 'lightgreen', 'yellow']) draws a bar chart on ax2
# labels are the categories in the x-axis.
# num for the heights of the bars.
# color sets the custom bar colors.

# %% [raw]
# ax2.set_title('Bar Chart (Subplot 2)') sets the title for the bar chart the second subplot

# %% [raw]
# ax2.set_xlabel('Candidate')
# ax2.set_ylabel('Votes')
# Adds labels to the x-axis ("Candidate") and y-axis ("Votes") for the bar chart.

# %% [raw]
# fig.suptitle('Voting Results', size=32) adds a main title to the entire figure and size=32 makes the font to size 32

# %% [raw]
# plt.tight_layout() automatically adjust the subplot for spacing and prevents overlapping with each other.

# %% [raw]
# plt.show() shows the final plot
