# %%
import seaborn as sns
data = [90, 80, 50, 42, 89, 78, 34, 70, 67, 73, 74, 80,60, 90, 90, 20]
sns.distplot(data)
# Out:
# C:\Users\Lacuesta\AppData\Local\Temp\ipykernel_7408\1675603633.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data)
# <Axes: ylabel='Density'>

# %% [raw]
# set of data containing 16 numerical values that gives the range in the bottom y axis and then creates a distribution plot using sns.distplot

# %%
import matplotlib.pyplot as plt
plt.title('Density Plot')
plt.xlabel('Score')
plt.ylabel('Density')
sns.distplot(data)
plt.show()
# Out:
# C:\Users\Lacuesta\AppData\Local\Temp\ipykernel_7408\3699222140.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data)

# %% [raw]
# Sets the title to density plot, labels the x-axis with the text 'score' and y-axis as 'density' then display it using plt.show

# %% [raw]
# For the error i think the distplot is outdated and need to use other function for it
